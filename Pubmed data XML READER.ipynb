# %%
import pubmed_parser as pp
import os
import gc
import sys
import pickle

# %% [markdown]
# ## Pubmed Rep

# %%
pubmed_path = os.path.join("/","backup","pubmed_archive","baseline_2018")
pubmed_store_path = os.path.join("/","backup","pubmed_archive_json")

# %%
from lxml import etree

def dir_tree_run(action, base_dir=pubmed_path):
    """
    Apply funcition "action" to the individual files from tree directory
    """
    _temp_f_name = ""
    for f_name in os.listdir(base_dir):
        _temp_f_name = os.path.join(base_dir,f_name)
        if os.path.isdir(_temp_f_name):
            dir_tree_run(action,_temp_f_name)
        else:
            action(_temp_f_name)


def open_pubmed_file(file_name, articles, error_files):
    try:
        articles.extend(pp.parse_medline_xml(file_name, year_info_only=False, nlm_category=False))
    except etree.XMLSyntaxError:
        error_files.append(file_name)
        print("Error on File " + file_name)

# %%
#example /backup/pubmed_archive/2011/11/pubs_2011-11_43.xml.gz
articles_tar_names = []
dir_tree_run(lambda x:articles_tar_names.append(x))
articles_tar_names = sorted(articles_tar_names)

# %%
## Multi process read of all the files!
from multiprocessing import Process

def open_xml(proc_id, xml_files):
    import pubmed_parser as pp
    
    print("[Process-{}] Started".format(proc_id))
    articles = []
    for file_name in xml_files:
        print(proc_id, file_name)
        try:
            articles.extend(pp.parse_medline_xml(file_name, year_info_only=False, nlm_category=False))
        except etree.XMLSyntaxError:
            error_files.append(file_name)
            print("Error on File " + file_name)
            
    articles_filter = filter(lambda x: (x["abstract"] is not None and len(x["abstract"])>0), articles)

    articles_mapped = list(map(lambda x:{"id":x["pmid"],"title":x["title"],"abstract":x["abstract"]},articles_filter))

    file_name = "/backup/pubmed_archive_json/pubmed_2018_{0:03}.p".format(proc_id)
    print("[Process-{}]: Store {}".format(proc_id, file_name))

    with open(file_name, "wb") as f:
        pickle.dump(articles, f)

    del articles
    print("[Process-{}] Ended".format(proc_id))

process = []
size = len(articles_tar_names)
itter = 50
for e,i in enumerate(range(0, size, itter)):
    process.append(Process(target=open_xml,args=(e, articles_tar_names[i:i+itter])))

print("[MULTIPROCESS LOOP] Starting", len(process), "process")
for p in process:
    p.start()

print("[MULTIPROCESS LOOP] Wait", len(process), "process")
for p in process:
    p.join()
# Out:
# [MULTIPROCESS LOOP] Starting 19 process
# [Process-0] Started
# 0 /backup/pubmed_archive/baseline_2018/pubmed18n0001.xml.gz
# [Process-1] Started
# 1 /backup/pubmed_archive/baseline_2018/pubmed18n0051.xml.gz
# [Process-2] Started
# 2 /backup/pubmed_archive/baseline_2018/pubmed18n0101.xml.gz
# [Process-3] Started
# 3 /backup/pubmed_archive/baseline_2018/pubmed18n0151.xml.gz
# [Process-4] Started
# 4 /backup/pubmed_archive/baseline_2018/pubmed18n0201.xml.gz
# [Process-5] Started
# 5 /backup/pubmed_archive/baseline_2018/pubmed18n0251.xml.gz
# [Process-6] Started
# 6 /backup/pubmed_archive/baseline_2018/pubmed18n0301.xml.gz
# [Process-7] Started
# 7 /backup/pubmed_archive/baseline_2018/pubmed18n0351.xml.gz
# [Process-8] Started
# 8 /backup/pubmed_archive/baseline_2018/pubmed18n0401.xml.gz
# [Process-9] Started
# 9 /backup/pubmed_archive/baseline_2018/pubmed18n0451.xml.gz
# 10 /backup/pubmed_archive/baseline_2018/pubmed18n0501.xml.gz
# 11 /backup/pubmed_archive/baseline_2018/pubmed18n0551.xml.gz
# [Process-10] Started
# [Process-11] Started
# [Process-12] Started
# 12 /backup/pubmed_archive/baseline_2018/pubmed18n0601.xml.gz
# [Process-13] Started
# 13 /backup/pubmed_archive/baseline_2018/pubmed18n0651.xml.gz
# [Process-14] Started
# 14 /backup/pubmed_archive/baseline_2018/pubmed18n0701.xml.gz
# [Process-15] Started
# 15 /backup/pubmed_archive/baseline_2018/pubmed18n0751.xml.gz
# [Process-16] Started
# 16 /backup/pubmed_archive/baseline_2018/pubmed18n0801.xml.gz
# [Process-17] Started
# 17 /backup/pubmed_archive/baseline_2018/pubmed18n0851.xml.gz
# [Process-18] Started
# 18 /backup/pubmed_archive/baseline_2018/pubmed18n0901.xml.gz
# [MULTIPROCESS LOOP] Wait 19 process
# 8 /backup/pubmed_archive/baseline_2018/pubmed18n0402.xml.gz
# 0 /backup/pubmed_archive/baseline_2018/pubmed18n0002.xml.gz
# 9 /backup/pubmed_archive/baseline_2018/pubmed18n0452.xml.gz
# 11 /backup/pubmed_archive/baseline_2018/pubmed18n0552.xml.gz
# 1 /backup/pubmed_archive/baseline_2018/pubmed18n0052.xml.gz
# 4 /backup/pubmed_archive/baseline_2018/pubmed18n0202.xml.gz
# 6 /backup/pubmed_archive/baseline_2018/pubmed18n0302.xml.gz
# 3 /backup/pubmed_archive/baseline_2018/pubmed18n0152.xml.gz
# 2 /backup/pubmed_archive/baseline_2018/pubmed18n0102.xml.gz
# 14 /backup/pubmed_archive/baseline_2018/pubmed18n0702.xml.gz
# 5 /backup/pubmed_archive/baseline_2018/pubmed18n0252.xml.gz
# 15 /backup/pubmed_archive/baseline_2018/pubmed18n0752.xml.gz
# 7 /backup/pubmed_archive/baseline_2018/pubmed18n0352.xml.gz
# 10 /backup/pubmed_archive/baseline_2018/pubmed18n0502.xml.gz
# 13 /backup/pubmed_archive/baseline_2018/pubmed18n0652.xml.gz
# 12 /backup/pubmed_archive/baseline_2018/pubmed18n0602.xml.gz
# 18 /backup/pubmed_archive/baseline_2018/pubmed18n0902.xml.gz
# 17 /backup/pubmed_archive/baseline_2018/pubmed18n0852.xml.gz
# 16 /backup/pubmed_archive/baseline_2018/pubmed18n0802.xml.gz
# 9 /backup/pubmed_archive/baseline_2018/pubmed18n
xml.gz
# 4 /backup/pubmed_archive/baseline_2018/pubmed18n0248.xml.gz
# 8 /backup/pubmed_archive/baseline_2018/pubmed18n0450.xml.gz
# 3 /backup/pubmed_archive/baseline_2018/pubmed18n0200.xml.gz
# 2 /backup/pubmed_archive/baseline_2018/pubmed18n0147.xml.gz
# 14 /backup/pubmed_archive/baseline_2018/pubmed18n0739.xml.gz
# 5 /backup/pubmed_archive/baseline_2018/pubmed18n0297.xml.gz
# [Process-8]: Store /backup/pubmed_archive_json/pubmed_2018_008.p
# 1 /backup/pubmed_archive/baseline_2018/pubmed18n0096.xml.gz
# 17 /backup/pubmed_archive/baseline_2018/pubmed18n0886.xml.gz
# 13 /backup/pubmed_archive/baseline_2018/pubmed18n0690.xml.gz
# 11 /backup/pubmed_archive/baseline_2018/pubmed18n0593.xml.gz
# 15 /backup/pubmed_archive/baseline_2018/pubmed18n0786.xml.gz
# 16 /backup/pubmed_archive/baseline_2018/pubmed18n0834.xml.gz
# 10 /backup/pubmed_archive/baseline_2018/pubmed18n0541.xml.gz
# [Process-0]: Store /backup/pubmed_archive_json/pubmed_2018_000.p
# 6 /backup/pubmed_archive/baseline_2018/pubmed18n0347.xml.gz
# 4 /backup/pubmed_archive/baseline_2018/pubmed18n0249.xml.gz
# 9 /backup/pubmed_archive/baseline_2018/pubmed18n0498.xml.gz
# 12 /backup/pubmed_archive/baseline_2018/pubmed18n0640.xml.gz
# [Process-8] Ended
# 7 /backup/pubmed_archive/baseline_2018/pubmed18n0391.xml.gz
# [Process-3]: Store /backup/pubmed_archive_json/pubmed_2018_003.p
# [Process-0] Ended
# 2 /backup/pubmed_archive/baseline_2018/pubmed18n0148.xml.gz
# 5 /backup/pubmed_archive/baseline_2018/pubmed18n0298.xml.gz
# 1 /backup/pubmed_archive/baseline_2018/pubmed18n0097.xml.gz
# 13 /backup/pubmed_archive/baseline_2018/pubmed18n0691.xml.gz
# 17 /backup/pubmed_archive/baseline_2018/pubmed18n0887.xml.gz
# 11 /backup/pubmed_archive/baseline_2018/pubmed18n0594.xml.gz
# [Process-3] Ended
# 4 /backup/pubmed_archive/baseline_2018/pubmed18n0250.xml.gz
# 14 /backup/pubmed_archive/baseline_2018/pubmed18n0740.xml.gz
# 10 /backup/pubmed_archive/baseline_2018/pubmed18n0542.xml.gz
# 7 /backup/pubmed_archive/baseline_2018/pubmed18n0392.xml.gz
# 6 /backup/pubmed_archive/baseline_2018/pubmed18n0348.xml.gz
# 5 /backup/pubmed_archive/baseline_2018/pubmed18n0299.xml.gz
# 15 /backup/pubmed_archive/baseline_2018/pubmed18n0787.xml.gz
# 9 /backup/pubmed_archive/baseline_2018/pubmed18n0499.xml.gz
# 1 /backup/pubmed_archive/baseline_2018/pubmed18n0098.xml.gz
# 16 /backup/pubmed_archive/baseline_2018/pubmed18n0835.xml.gz
# 2 /backup/pubmed_archive/baseline_2018/pubmed18n0149.xml.gz
# 12 /backup/pubmed_archive/baseline_2018/pubmed18n0641.xml.gz
# 13 /backup/pubmed_archive/baseline_2018/pubmed18n0692.xml.gz
# 11 /backup/pubmed_archive/baseline_2018/pubmed18n0595.xml.gz
# 17 /backup/pubmed_archive/baseline_2018/pubmed18n0888.xml.gz
# [Process-4]: Store /backup/pubmed_archive_json/pubmed_2018_004.p
# 7 /backup/pubmed_archive/baseline_2018/pubmed18n0393.xml.gz
# 1 /backup/pubmed_archive/baseline_2018/pubmed18n0099.xml.gz
# 5 /backup/pubmed_archive/baseline_2018/pubmed18n0300.xml.gz
# [Process-4] Ended
# 6 /backup/pubmed_archive/baseline_2018/pubmed18n0349.xml.gz
# 10 /backup/pubmed_archive/baseline_2018/pubmed18n0543.xml.gz
# 2 /backup/pubmed_archive/baseline_2018/pubmed18n0150.xml.gz
# 12 /backup/pubmed_archive/baseline_2018/pubmed18n0642.xml.gz
# 14 /backup/pubmed_archive/baseline_2018/pubmed18n0741.xml.gz
# 9 /backup/pubmed_archive/baseline_2018/pubmed18n0500.xml.gz
# 11 /backup/pubmed_archive/baseline_2018/pubmed18n0596.xml.gz
# 13 /backup/pubmed_archive/baseline_2018/pubmed18n0693.xml.gz
# 15 /backup/pubmed_archive/baseline_2018/pubmed18n0788.xml.gz
# 7 /backup/pubmed_archive/baseline_2018/pubmed18n0394.xml.gz
# 1 /backup/pubmed_archive/baseline_2018/pubmed18n0100.xml.gz
# 17 /backup/pubmed_archive/baseline_2018/pubmed18n0889.xml.gz
# 16 /backup/pubmed_archive/baseline_2018/pubmed18n0836.xml.gz
# [Process-5]: Store /backup/pubmed_archive_json/pubmed_2018_005.p
# [Process-2]: Store /backup/pubmed_archive_json/pubmed_2018_002.p
# 6 /backup/pubmed_archive/baseline_2018/pubmed18n0350.xml.gz
# 12 /backup/pubmed_archive/baseline_2018/pubmed18n0643.xml.gz
# [Process-9]: Store /backup/pubmed_archive_json/pubmed_2018_009.p
# 11 /backup/pubmed_archive/baseline_2018/pubmed18n0597.xml.gz
# 10 /backup/pubmed_archive/baseline_2018/pubmed18n0544.xml.gz
# [Process-5] Ended
# [Process-2] Ended
# [Process-1]: Store /backup/pubmed_archive_json/pubmed_2018_001.p
# 15 /backup/pubmed_archive/baseline_2018/pubmed18n0789.xml.gz
# 14 /backup/pubmed_archive/baseline_2018/pubmed18n0742.xml.gz
# [Process-9] Ended
# 17 /backup/pubmed_archive/baseline_2018/pubmed18n0890.xml.gz
# 7 /backup/pubmed_archive/baseline_2018/pubmed18n0395.xml.gz
# 13 /backup/pubmed_archive/baseline_2018/pubmed18n0694.xml.gz
# 16 /backup/pubmed_archive/baseline_2018/pubmed18n0837.xml.gz
# [Process-1] Ended
# [Process-6]: Store /backup/pubmed_archive_json/pubmed_2018_006.p
# 10 /backup/pubmed_archive/baseline_2018/pubmed18n0545.xml.gz
# 12 /backup/pubmed_archive/baseline_2018/pubmed18n0644.xml.gz
# 11 /backup/pubmed_archive/baseline_2018/pubmed18n0598.xml.gz
# [Process-6] Ended
# 15 /backup/pubmed_archive/baseline_2018/pubmed18n0790.xml.gz
# 7 /backup/pubmed_archive/baseline_2018/pubmed18n0396.xml.gz
# 14 /backup/pubmed_archive/baseline_2018/pubmed18n0743.xml.gz
# 17 /backup/pubmed_archive/baseline_2018/pubmed18n0891.xml.gz
# 13 /backup/pubmed_archive/baseline_2018/pubmed18n0695.xml.gz
# 10 /backup/pubmed_archive/baseline_2018/pubmed18n0546.xml.gz
# 16 /backup/pubmed_archive/baseline_2018/pubmed18n0838.xml.gz
# 12 /backup/pubmed_archive/baseline_2018/pubmed18n0645.xml.gz
# 11 /backup/pubmed_archive/baseline_2018/pubmed18n0599.xml.gz
# 7 /backup/pubmed_archive/baseline_2018/pubmed18n0397.xml.gz
# 14 /backup/pubmed_archive/baseline_2018/pubmed18n0744.xml.gz
# 15 /backup/pubmed_archive/baseline_2018/pubmed18n0791.xml.gz
# 12 /backup/pubmed_archive/baseline_2018/pubmed18n0646.xml.gz
# 17 /backup/pubmed_archive/baseline_2018/pubmed18n0892.xml.gz
# 13 /backup/pubmed_archive/baseline_2018/pubmed18n0696.xml.gz
# 10 /backup/pubmed_archive/baseline_2018/pubmed18n0547.xml.gz
# 11 /backup/pubmed_archive/baseline_2018/pubmed18n0600.xml.gz
# 16 /backup/pubmed_archive/baseline_2018/pubmed18n0839.xml.gz
# 7 /backup/pubmed_archive/baseline_2018/pubmed18n0398.xml.gz
# 12 /backup/pubmed_archive/baseline_2018/pubmed18n0647.xml.gz
# 14 /backup/pubmed_archive/baseline_2018/pubmed18n0745.xml.gz
# 15 /backup/pubmed_archive/baseline_2018/pubmed18n0792.xml.gz
# 13 /backup/pubmed_archive/baseline_2018/pubmed18n0697.xml.gz
# 17 /backup/pubmed_archive/baseline_2018/pubmed18n0893.xml.gz
# 10 /backup/pubmed_archive/baseline_2018/pubmed18n0548.xml.gz
# [Process-11]: Store /backup/pubmed_archive_json/pubmed_2018_011.p
# 7 /backup/pubmed_archive/baseline_2018/pubmed18n0399.xml.gz
# 16 /backup/pubmed_archive/baseline_2018/pubmed18n0840.xml.gz
# [Process-11] Ended
# 14 /backup/pubmed_archive/baseline_2018/pubmed18n0746.xml.gz
# 12 /backup/pubmed_archive/baseline_2018/pubmed18n0648.xml.gz
# 15 /backup/pubmed_archive/baseline_2018/pubmed18n0793.xml.gz
# 13 /backup/pubmed_archive/baseline_2018/pubmed18n0698.xml.gz
# 10 /backup/pubmed_archive/baseline_2018/pubmed18n0549.xml.gz
# 17 /backup/pubmed_archive/baseline_2018/pubmed18n0894.xml.gz
# 7 /backup/pubmed_archive/baseline_2018/pubmed18n0400.xml.gz
# 16 /backup/pubmed_archive/baseline_2018/pubmed18n0841.xml.gz
# 12 /backup/pubmed_archive/baseline_2018/pubmed18n0649.xml.gz
# 14 /backup/pubmed_archive/baseline_2018/pubmed18n0747.xml.gz
# 10 /backup/pubmed_archive/baseline_2018/pubmed18n0550.xml.gz
# 13 /backup/pubmed_archive/baseline_2018/pubmed18n0699.xml.gz
# 15 /backup/pubmed_archive/baseline_2018/pubmed18n0794.xml.gz
# 17 /backup/pubmed_archive/baseline_2018/pubmed18n0895.xml.gz
# [Process-7]: Store /backup/pubmed_archive_json/pubmed_2018_007.p
# 16 /backup/pubmed_archive/baseline_2018/pubmed18n0842.xml.gz
# [Process-7] Ended
# 12 /backup/pubmed_archive/baseline_2018/pubmed18n0650.xml.gz
# 14 /backup/pubmed_archive/baseline_2018/pubmed18n0748.xml.gz
# [Process-10]: Store /backup/pubmed_archive_json/pubmed_2018_010.p
# 13 /backup/pubmed_archive/baseline_2018/pubmed18n0700.xml.gz
# 15 /backup/pubmed_archive/baseline_2018/pubmed18n0795.xml.gz
# 17 /backup/pubmed_archive/baseline_2018/pubmed18n0896.xml.gz
# [Process-10] Ended
# 16 /backup/pubmed_archive/baseline_2018/pubmed18n0843.xml.gz
# [Process-12]: Store /backup/pubmed_archive_json/pubmed_2018_012.p
# 14 /backup/pubmed_archive/baseline_2018/pubmed18n0749.xml.gz
# [Process-13]: Store /backup/pubmed_archive_json/pubmed_2018_013.p
# 17 /backup/pubmed_archive/baseline_2018/pubmed18n0897.xml.gz
# 15 /backup/pubmed_archive/baseline_2018/pubmed18n0796.xml.gz
# [Process-12] Ended
# [Process-13] Ended
# 16 /backup/pubmed_archive/baseline_2018/pubmed18n0844.xml.gz
# 14 /backup/pubmed_archive/baseline_2018/pubmed18n0750.xml.gz
# 17 /backup/pubmed_archive/baseline_2018/pubmed18n0898.xml.gz
# 15 /backup/pubmed_archive/baseline_2018/pubmed18n0797.xml.gz
# [Process-14]: Store /backup/pubmed_archive_json/pubmed_2018_014.p
# 16 /backup/pubmed_archive/baseline_2018/pubmed18n0845.xml.gz
# 17 /backup/pubmed_archive/baseline_2018/pubmed18n0899.xml.gz
# 15 /backup/pubmed_archive/baseline_2018/pubmed18n0798.xml.gz
# [Process-14] Ended
# 16 /backup/pubmed_archive/baseline_2018/pubmed18n0846.xml.gz
# 17 /backup/pubmed_archive/baseline_2018/pubmed18n0900.xml.gz
# 15 /backup/pubmed_archive/baseline_2018/pubmed18n0799.xml.gz
# 16 /backup/pubmed_archive/baseline_2018/pubmed18n0847.xml.gz
# [Process-17]: Store /backup/pubmed_archive_json/pubmed_2018_017.p
# 15 /backup/pubmed_archive/baseline_2018/pubmed18n0800.xml.gz
# [Process-17] Ended
# 16 /backup/pubmed_archive/baseline_2018/pubmed18n0848.xml.gz
# [Process-15]: Store /backup/pubmed_archive_json/pubmed_2018_015.p
# [Process-15] Ended
# 16 /backup/pubmed_archive/baseline_2018/pubmed18n0849.xml.gz
# 16 /backup/pubmed_archive/baseline_2018/pubmed18n0850.xml.gz
# [Process-16]: Store /backup/pubmed_archive_json/pubmed_2018_016.p
# [Process-16] Ended

# %%
import json

json_format = sorted(list(filter(lambda x: "pubmed_2018_" in x, os.listdir("/backup/pubmed_archive_json"))))

articles = []

for f_n in json_format:
    with open(os.path.join("/backup/pubmed_archive_json",f_n), "rb") as f:
        articles.extend(pickle.load(f))
# Out:
# 27837540
# Save file /backup/pubmed_archive_json/pubmedMedline_2018_00000000_to_03000000 :Done
# Save file /backup/pubmed_archive_json/pubmedMedline_2018_03000000_to_06000000 :Done
# Save file /backup/pubmed_archive_json/pubmedMedline_2018_06000000_to_09000000 :Done
# Save file /backup/pubmed_archive_json/pubmedMedline_2018_09000000_to_12000000 :Done
# Save file /backup/pubmed_archive_json/pubmedMedline_2018_15000000_to_18000000 :Done
# Save file /backup/pubmed_archive_json/pubmedMedline_2018_18000000_to_21000000 :Done
# Save file /backup/pubmed_archive_json/pubmedMedline_2018_21000000_to_24000000 :Done
# Save file /backup/pubmed_archive_json/pubmedMedline_2018_24000000_to_27000000 :Done
# Save file /backup/pubmed_archive_json/pubmedMedline_2018_27000000_to_27837540 :Done

# %%
size = len(articles)
print(size)
itter = int(3e6)

for i in range(0, size, itter):
    file_name = "/backup/pubmed_archive_json/pubmedMedline_2018_{0:08}_to_{1:08}".format(i, min(size, i+itter))
    print("Save file",file_name,":",end="")
    json.dump(articles[i:i+itter], open(file_name,"w"))
    print("Done")

# %%
articles_new

size = len(articles_new)
print(size)
itter = int(3e6)

for i in range(0, size, itter):
    file_name = "/backup/pubmed_archive_json/pubmedMedline_2018_{0:08}_to_{1:08}".format(i, min(size, i+itter))
    print("Save file",file_name,":",end="")
    json.dump(articles_new[i:i+itter], open(file_name,"w"))
    print("Done")
# Out:
# 17731043
# Save file /backup/pubmed_archive_json/pubmedMedline_2018_00000000_to_03000000 :Done
# Save file /backup/pubmed_archive_json/pubmedMedline_2018_03000000_to_06000000 :Done
# Save file /backup/pubmed_archive_json/pubmedMedline_2018_06000000_to_09000000 :Done
# Save file /backup/pubmed_archive_json/pubmedMedline_2018_09000000_to_12000000 :Done
# Save file /backup/pubmed_archive_json/pubmedMedline_2018_12000000_to_15000000 :Done
# Save file /backup/pubmed_archive_json/pubmedMedline_2018_15000000_to_17731043 :Done

# %%
articles_filter = filter(lambda x: (x["abstract"] is not None and len(x["abstract"])>0), articles)

articles_mapped = list(map(lambda x:{"id":x["pmid"],"title":x["title"],"abstract":x["abstract"]},articles_filter))

size = len(articles_mapped)
itter = int(3e6)
for i in range(0, size, itter):
    file_name = "/backup/pubmed_archive_json/pubmed_2018_{0:08}_to_{1:08}".format(i, min(size, i+itter))
    print("Save file",file_name,":",end="")
    json.dump(articles_mapped[i:i+itter], open(file_name,"w"))
    print("Done")
# Out:
# Save file /backup/pubmed_archive_json/pubmed_tit_abs_00000000_to_03000000 :

# %%
fast_reduce = []    

for i,article in enumerate(articles):
    if i%100000==0:
        print("Articles filter:",i,end="\r")
    
    if len(article["abstract"])==0:
        continue
    fast_reduce.append(articles[i])
    

print("Total articles:",len(articles))
print("Articles with empty abstract",len(zero_index))
print("Total of articles without empty abstract",len(fast_reduce))

#Clean up some vars
del articles
articles = fast_reduce
del fast_reduce
del zero_index
gc.collect()
# Out:
# ['pubmed_dump_20470668_to_23293992.json',
#  'pubmed_dump_08922282_to_11867708.json',
#  'Pubmed Collection analysis.ipynb',
#  'BAD_XML_FORMAT',
#  'pubmed_dump_14837500_to_17728469.json',
#  'pubmed_dump_23293993_to_25615338.json',
#  'pubmed_dump_00000000_to_02974738.json',
#  '__init__.py',
#  '__pycache__',
#  'pubmed_dump_02974739_to_05951961.json',
#  'pubmed_dump_05951962_to_08922281.json',
#  '.ipynb_checkpoints',
#  'pubmed_dump_11867709_to_14837499.json',
#  'Pubmed data XML READER.ipynb',
#  'pubmed_dump_17728470_to_20470667.json',
#  'pubmed_helper.py']

# %%
import json
#Save in disk
FULL_SAVE = True #save all the xml parametrs, if FALS only  title, abstract and pmid will be saved

if FULL_SAVE == False:
    small_articles=list(map(lambda x:{"pmid":x["pmid"],"title":x["title"],"abstract":x["abstract"]},articles))
    _backup_articles = articles
    articles = small_articles

batch = list(range(0,len(articles),int(3e6)))
batch[-1] = len(articles)-1

for i in range(0,len(batch)-1):
    file_name = "/backup/pubmed_archive_json/pubmed_full_{0:08}_to_{1:08}".format(batch[i],batch[i+1])
    print("Save file",file_name,":",end="")
    json.dump(articles[batch[i]:batch[i+1]],open(file_name,"w"))
    print("Done")
    
#articles = _backup_articles

gc.collect()
# Out:
# Save file /backup/pubmed_archive_json/pubmed_full_00000000_to_03000000 :Done
# Save file /backup/pubmed_archive_json/pubmed_full_03000000_to_06000000 :Done
# Save file /backup/pubmed_archive_json/pubmed_full_06000000_to_09000000 :Done
# Save file /backup/pubmed_archive_json/pubmed_full_09000000_to_12000000 :Done
# Save file /backup/pubmed_archive_json/pubmed_full_12000000_to_15000000 :Done
# Save file /backup/pubmed_archive_json/pubmed_full_15000000_to_18000000 :Done
# Save file /backup/pubmed_archive_json/pubmed_full_18000000_to_21000000 :Done
# Save file /backup/pubmed_archive_json/pubmed_full_21000000_to_24000000 :Done
# Save file /backup/pubmed_archive_json/pubmed_full_24000000_to_27000000 :Done
# Save file /backup/pubmed_archive_json/pubmed_full_27000000_to_30862349 :Done
# 557

# %%
# Out:
# 32
